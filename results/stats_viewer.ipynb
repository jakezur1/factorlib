# %%
load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
autoreload 2

# %%
from factorlib.statistics import Statistics

# %%
stats = Statistics()
stats.load('wfo_stats.p')
stats.print_statistics_report()
# Out:
# Empty Statistics object created. Load object using load(path: str) method.
#
# FACTOR MODEL ANALYSIS REPORT
# ==============================
# Relative to baseline models:
# Spearman correlation: 0.017664135196079633
# /Users/jakezur/Documents/finance/factorlib/venv/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4916: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# +--------------+---------+--------+----------+---------+
# |   metric:    | factors |  spy   | buy_hold |  random |
# +--------------+---------+--------+----------+---------+
# | cum. returns |  33.48% | 31.22% |  33.87%  | -26.16% |
# |    sharpe    |  2.315  | 2.233  |  2.307   |  -2.372 |
# |   sortino    |  3.379  | 3.251  |  3.373   |  -3.092 |
# |     cagr     |  33.7%  | 31.42% |  34.08%  | -26.28% |
# |  avg rtrns   |  0.12%  | 0.11%  |  0.12%   |  -0.12% |
# | max drawdown |  -6.23% | -6.62% |  -6.84%  | -27.54% |
# |  volatility  |  12.87% | 12.56% |  13.05%  |  12.49% |
# |   win rate   |  60.32% | 59.52% |  59.92%  |  42.63% |
# +--------------+---------+--------+----------+---------+

# %%
stats.compute_correlations()
# Out:
# <style type="text/css">
# #T_fabf4_row0_col0, #T_fabf4_row1_col1, #T_fabf4_row2_col2, #T_fabf4_row3_col3, #T_fabf4_row4_col4, #T_fabf4_row5_col5, #T_fabf4_row6_col6, #T_fabf4_row7_col7, #T_fabf4_row8_col8, #T_fabf4_row9_col9, #T_fabf4_row10_col10, #T_fabf4_row10_col11, #T_fabf4_row11_col10, #T_fabf4_row11_col11, #T_fabf4_row12_col12, #T_fabf4_row13_col13, #T_fabf4_row14_col14, #T_fabf4_row15_col15, #T_fabf4_row16_col16, #T_fabf4_row17_col17, #T_fabf4_row18_col18, #T_fabf4_row19_col19, #T_fabf4_row20_col20, #T_fabf4_row21_col21, #T_fabf4_row22_col22, #T_fabf4_row23_col23, #T_fabf4_row24_col24, #T_fabf4_row25_col25, #T_fabf4_row26_col26, #T_fabf4_row27_col27, #T_fabf4_row28_col28, #T_fabf4_row29_col29, #T_fabf4_row30_col30, #T_fabf4_row31_col31, #T_fabf4_row32_col32, #T_fabf4_row33_col33, #T_fabf4_row34_col34, #T_fabf4_row35_col35, #T_fabf4_row36_col36 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_fabf4_row0_col1, #T_fabf4_row1_col0, #T_fabf4_row3_col8, #T_fabf4_row3_col34, #T_fabf4_row4_col20, #T_fabf4_row4_col35, #T_fabf4_row8_col3, #T_fabf4_row10_col21, #T_fabf4_row10_col36, #T_fabf4_row11_col36, #T_fabf4_row18_col22, #T_fabf4_row20_col4, #T_fabf4_row21_col10, #T_fabf4_row21_col28, #T_fabf4_row22_col18, #T_fabf4_row28_col21, #T_fabf4_row34_col3, #T_fabf4_row35_col4, #T_fabf4_row36_col10, #T_fabf4_row36_col11 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_fabf4_row0_col2, #T_fabf4_row2_col0, #T_fabf4_row18_col30, #T_fabf4_row30_col18 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_fabf4_row0_col3, #T_fabf4_row2_col10, #T_fabf4_row3_col0, #T_fabf4_row10_col2, #T_fabf4_row17_col18, #T_fabf4_row18_col17, #T_fabf4_row24_col26, #T_fabf4_row26_col24 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_fabf4_row0_col4, #T_fabf4_row4_col0 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_fabf4_row0_col5, #T_fabf4_row0_col28, #T_fabf4_row1_col26, #T_fabf4_row1_col31, #T_fabf4_row2_col36, #T_fabf4_row3_col31, #T_fabf4_row4_col29, #T_fabf4_row5_col0, #T_fabf4_row6_col17, #T_fabf4_row7_col12, #T_fabf4_row7_col14, #T_fabf4_row7_col21, #T_fabf4_row7_col28, #T_fabf4_row7_col34, #T_fabf4_row7_col36, #T_fabf4_row8_col25, #T_fabf4_row8_col33, #T_fabf4_row9_col28, #T_fabf4_row10_col14, #T_fabf4_row10_col28, #T_fabf4_row11_col28, #T_fabf4_row12_col7, #T_fabf4_row13_col30, #T_fabf4_row13_col32, #T_fabf4_row14_col7, #T_fabf4_row14_col10, #T_fabf4_row17_col6, #T_fabf4_row19_col25, #T_fabf4_row19_col28, #T_fabf4_row20_col22, #T_fabf4_row20_col30, #T_fabf4_row21_col7, #T_fabf4_row21_col23, #T_fabf4_row21_col33, #T_fabf4_row22_col20, #T_fabf4_row22_col35, #T_fabf4_row23_col21, #T_fabf4_row25_col8, #T_fabf4_row25_col19, #T_fabf4_row26_col1, #T_fabf4_row28_col0, #T_fabf4_row28_col7, #T_fabf4_row28_col9, #T_fabf4_row28_col10, #T_fabf4_row28_col11, #T_fabf4_row28_col19, #T_fabf4_row28_col35, #T_fabf4_row29_col4, #T_fabf4_row30_col13, #T_fabf4_row30_col20, #T_fabf4_row31_col1, #T_fabf4_row31_col3, #T_fabf4_row32_col13, #T_fabf4_row33_col8, #T_fabf4_row33_col21, #T_fabf4_row34_col7, #T_fabf4_row35_col22, #T_fabf4_row35_col28, #T_fabf4_row36_col2, #T_fabf4_row36_col7 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_fabf4_row0_col6, #T_fabf4_row6_col0 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_fabf4_row0_col7, #T_fabf4_row7_col0 {
#   background-color: #abdc8d;
#   color: #000000;
# }
# #T_fabf4_row0_col8, #T_fabf4_row0_col19, #T_fabf4_row8_col0, #T_fabf4_row8_col13, #T_fabf4_row13_col8, #T_fabf4_row19_col0, #T_fabf4_row28_col33, #T_fabf4_row33_col28 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_fabf4_row0_col9, #T_fabf4_row9_col0, #T_fabf4_row20_col35, #T_fabf4_row35_col20 {
#   background-color: #00532f;
#   color: #f1f1f1;
# }
# #T_fabf4_row0_col10, #T_fabf4_row10_col0 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_fabf4_row0_col11, #T_fabf4_row11_col0 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_fabf4_row0_col12, #T_fabf4_row6_col12, #T_fabf4_row10_col15, #T_fabf4_row11_col15, #T_fabf4_row12_col0, #T_fabf4_row12_col6, #T_fabf4_row12_col27, #T_fabf4_row14_col19, #T_fabf4_row15_col10, #T_fabf4_row15_col11, #T_fabf4_row17_col25, #T_fabf4_row18_col35, #T_fabf4_row19_col14, #T_fabf4_row20_col27, #T_fabf4_row25_col17, #T_fabf4_row27_col12, #T_fabf4_row27_col20, #T_fabf4_row35_col18 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_fabf4_row0_col13, #T_fabf4_row13_col0 {
#   background-color: #278946;
#   color: #f1f1f1;
# }
# #T_fabf4_row0_col14, #T_fabf4_row0_col18, #T_fabf4_row0_col29, #T_fabf4_row0_col33, #T_fabf4_row1_col17, #T_fabf4_row1_col33, #T_fabf4_row2_col24, #T_fabf4_row2_col26, #T_fabf4_row2_col31, #T_fabf4_row2_col34, #T_fabf4_row3_col12, #T_fabf4_row3_col14, #T_fabf4_row3_col18, #T_fabf4_row3_col23, #T_fabf4_row3_col30, #T_fabf4_row5_col7, #T_fabf4_row6_col15, #T_fabf4_row6_col24, #T_fabf4_row6_col26, #T_fabf4_row6_col27, #T_fabf4_row6_col31, #T_fabf4_row6_col32, #T_fabf4_row7_col5, #T_fabf4_row7_col25, #T_fabf4_row7_col31, #T_fabf4_row8_col22, #T_fabf4_row8_col27, #T_fabf4_row9_col17, #T_fabf4_row9_col25, #T_fabf4_row9_col30, #T_fabf4_row9_col32, #T_fabf4_row10_col29, #T_fabf4_row11_col18, #T_fabf4_row11_col23, #T_fabf4_row11_col29, #T_fabf4_row11_col32, #T_fabf4_row12_col3, #T_fabf4_row12_col21, #T_fabf4_row12_col34, #T_fabf4_row12_col36, #T_fabf4_row14_col0, #T_fabf4_row14_col3, #T_fabf4_row14_col24, #T_fabf4_row14_col27, #T_fabf4_row14_col29, #T_fabf4_row15_col6, #T_fabf4_row15_col18, #T_fabf4_row15_col24, #T_fabf4_row15_col26, #T_fabf4_row15_col27, #T_fabf4_row16_col24, #T_fabf4_row16_col26, #T_fabf4_row16_col27, #T_fabf4_row17_col1, #T_fabf4_row17_col9, #T_fabf4_row18_col0, #T_fabf4_row18_col3, #T_fabf4_row18_col11, #T_fabf4_row18_col15, #T_fabf4_row19_col24, #T_fabf4_row19_col32, #T_fabf4_row20_col24, #T_fabf4_row21_col12, #T_fabf4_row21_col32, #T_fabf4_row22_col8, #T_fabf4_row23_col3, #T_fabf4_row23_col11, #T_fabf4_row23_col34, #T_fabf4_row24_col2, #T_fabf4_row24_col6, #T_fabf4_row24_col14, #T_fabf4_row24_col15, #T_fabf4_row24_col16, #T_fabf4_row24_col19, #T_fabf4_row24_col20, #T_fabf4_row25_col7, #T_fabf4_row25_col9, #T_fabf4_row26_col2, #T_fabf4_row26_col6, #T_fabf4_row26_col15, #T_fabf4_row26_col16, #T_fabf4_row27_col6, #T_fabf4_row27_col8, #T_fabf4_row27_col14, #T_fabf4_row27_col15, #T_fabf4_row27_col16, #T_fabf4_row29_col0, #T_fabf4_row29_col10, #T_fabf4_row29_col11, #T_fabf4_row29_col14, #T_fabf4_row30_col3, #T_fabf4_row30_col9, #T_fabf4_row31_col2, #T_fabf4_row31_col6, #T_fabf4_row31_col7, #T_fabf4_row32_col6, #T_fabf4_row32_col9, #T_fabf4_row32_col11, #T_fabf4_row32_col19, #T_fabf4_row32_col21, #T_fabf4_row33_col0, #T_fabf4_row33_col1, #T_fabf4_row34_col2, #T_fabf4_row34_col12, #T_fabf4_row34_col23, #T_fabf4_row36_col12 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_fabf4_row0_col15, #T_fabf4_row10_col20, #T_fabf4_row10_col34, #T_fabf4_row10_col35, #T_fabf4_row15_col0, #T_fabf4_row20_col10, #T_fabf4_row25_col34, #T_fabf4_row34_col10, #T_fabf4_row34_col25, #T_fabf4_row35_col10 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_fabf4_row0_col16, #T_fabf4_row1_col12, #T_fabf4_row2_col20, #T_fabf4_row2_col21, #T_fabf4_row2_col22, #T_fabf4_row2_col27, #T_fabf4_row2_col30, #T_fabf4_row3_col26, #T_fabf4_row4_col32, #T_fabf4_row5_col19, #T_fabf4_row5_col34, #T_fabf4_row12_col1, #T_fabf4_row12_col30, #T_fabf4_row13_col25, #T_fabf4_row16_col0, #T_fabf4_row17_col35, #T_fabf4_row19_col5, #T_fabf4_row20_col2, #T_fabf4_row21_col2, #T_fabf4_row21_col30, #T_fabf4_row22_col2, #T_fabf4_row25_col13, #T_fabf4_row26_col3, #T_fabf4_row27_col2, #T_fabf4_row30_col2, #T_fabf4_row30_col12, #T_fabf4_row30_col21, #T_fabf4_row30_col35, #T_fabf4_row32_col4, #T_fabf4_row32_col34, #T_fabf4_row34_col5, #T_fabf4_row34_col32, #T_fabf4_row35_col17, #T_fabf4_row35_col30 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_fabf4_row0_col17, #T_fabf4_row1_col5, #T_fabf4_row1_col18, #T_fabf4_row1_col25, #T_fabf4_row1_col27, #T_fabf4_row1_col29, #T_fabf4_row1_col30, #T_fabf4_row3_col33, #T_fabf4_row4_col10, #T_fabf4_row4_col12, #T_fabf4_ro
