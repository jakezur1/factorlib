# %%
load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
autoreload 2

# %%
from factorlib.statistics import Statistics

# %%
stats = Statistics()
stats.load('wfo_stats.p')
stats.print_statistics_report()
# Out:
# Empty Statistics object created. Load object using load(path: str) method.
#
# FACTOR MODEL ANALYSIS REPORT
# ==============================
# Relative to baseline models:
# Spearman correlation: 0.01559199602527752
# An input array is constant; the correlation coefficient is not defined.
# +--------------+---------+--------+----------+---------+
# |   metric:    | factors |  spy   | buy_hold |  random |
# +--------------+---------+--------+----------+---------+
# | cum. returns |  24.98% | 31.22% |  33.87%  | -26.42% |
# |    sharpe    |  1.817  | 2.233  |  2.307   |  -2.456 |
# |   sortino    |  2.677  | 3.251  |  3.373   |  -3.279 |
# |     cagr     |  25.13% | 31.42% |  34.08%  | -26.55% |
# |  avg rtrns   |  0.09%  | 0.11%  |  0.12%   |  -0.12% |
# | max drawdown |  -6.41% | -6.62% |  -6.84%  | -28.04% |
# |  volatility  |  12.75% | 12.56% |  13.05%  |  12.22% |
# |   win rate   |  55.95% | 59.52% |  59.92%  |  43.03% |
# +--------------+---------+--------+----------+---------+

# %%
stats.compute_correlations()
# Out:
# <style type="text/css">
# #T_d56ca_row0_col0, #T_d56ca_row1_col1, #T_d56ca_row2_col2, #T_d56ca_row3_col3, #T_d56ca_row4_col4, #T_d56ca_row5_col5, #T_d56ca_row6_col6, #T_d56ca_row7_col7, #T_d56ca_row8_col8, #T_d56ca_row9_col9, #T_d56ca_row10_col10, #T_d56ca_row10_col11, #T_d56ca_row11_col10, #T_d56ca_row11_col11, #T_d56ca_row12_col12, #T_d56ca_row13_col13, #T_d56ca_row14_col14, #T_d56ca_row15_col15, #T_d56ca_row16_col16, #T_d56ca_row17_col17, #T_d56ca_row18_col18, #T_d56ca_row19_col19, #T_d56ca_row20_col20, #T_d56ca_row21_col21, #T_d56ca_row22_col22, #T_d56ca_row24_col24, #T_d56ca_row25_col25, #T_d56ca_row27_col27, #T_d56ca_row28_col28, #T_d56ca_row29_col29, #T_d56ca_row30_col30, #T_d56ca_row32_col32, #T_d56ca_row33_col33, #T_d56ca_row34_col34, #T_d56ca_row35_col35, #T_d56ca_row36_col36 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_d56ca_row0_col1, #T_d56ca_row1_col0, #T_d56ca_row3_col8, #T_d56ca_row3_col34, #T_d56ca_row4_col35, #T_d56ca_row8_col3, #T_d56ca_row11_col21, #T_d56ca_row11_col34, #T_d56ca_row11_col36, #T_d56ca_row17_col36, #T_d56ca_row21_col11, #T_d56ca_row22_col27, #T_d56ca_row27_col22, #T_d56ca_row30_col34, #T_d56ca_row30_col36, #T_d56ca_row34_col3, #T_d56ca_row34_col11, #T_d56ca_row34_col30, #T_d56ca_row35_col4, #T_d56ca_row36_col11, #T_d56ca_row36_col17, #T_d56ca_row36_col30 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_d56ca_row0_col2, #T_d56ca_row2_col0, #T_d56ca_row3_col13, #T_d56ca_row13_col3 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_d56ca_row0_col3, #T_d56ca_row2_col10, #T_d56ca_row3_col0, #T_d56ca_row10_col2, #T_d56ca_row17_col18, #T_d56ca_row18_col17 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_d56ca_row0_col4, #T_d56ca_row4_col0 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_d56ca_row0_col5, #T_d56ca_row0_col32, #T_d56ca_row4_col10, #T_d56ca_row4_col22, #T_d56ca_row4_col34, #T_d56ca_row5_col0, #T_d56ca_row5_col6, #T_d56ca_row5_col9, #T_d56ca_row5_col35, #T_d56ca_row6_col5, #T_d56ca_row7_col14, #T_d56ca_row7_col21, #T_d56ca_row7_col29, #T_d56ca_row7_col36, #T_d56ca_row8_col24, #T_d56ca_row8_col29, #T_d56ca_row9_col5, #T_d56ca_row9_col30, #T_d56ca_row10_col4, #T_d56ca_row10_col14, #T_d56ca_row10_col29, #T_d56ca_row12_col27, #T_d56ca_row13_col16, #T_d56ca_row14_col7, #T_d56ca_row14_col10, #T_d56ca_row15_col16, #T_d56ca_row15_col30, #T_d56ca_row16_col13, #T_d56ca_row16_col15, #T_d56ca_row16_col30, #T_d56ca_row19_col32, #T_d56ca_row19_col33, #T_d56ca_row21_col7, #T_d56ca_row22_col4, #T_d56ca_row24_col8, #T_d56ca_row27_col12, #T_d56ca_row27_col32, #T_d56ca_row29_col7, #T_d56ca_row29_col8, #T_d56ca_row29_col10, #T_d56ca_row30_col9, #T_d56ca_row30_col15, #T_d56ca_row30_col16, #T_d56ca_row32_col0, #T_d56ca_row32_col19, #T_d56ca_row32_col27, #T_d56ca_row33_col19, #T_d56ca_row33_col35, #T_d56ca_row34_col4, #T_d56ca_row35_col5, #T_d56ca_row35_col33, #T_d56ca_row36_col7 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_d56ca_row0_col6, #T_d56ca_row6_col0 {
#   background-color: #1c7e40;
#   color: #f1f1f1;
# }
# #T_d56ca_row0_col7, #T_d56ca_row2_col7, #T_d56ca_row7_col0, #T_d56ca_row7_col2, #T_d56ca_row10_col19, #T_d56ca_row19_col10 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_d56ca_row0_col8, #T_d56ca_row8_col0, #T_d56ca_row15_col20, #T_d56ca_row20_col15 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_d56ca_row0_col9, #T_d56ca_row9_col0, #T_d56ca_row20_col35, #T_d56ca_row32_col33, #T_d56ca_row33_col32, #T_d56ca_row35_col20 {
#   background-color: #00542f;
#   color: #f1f1f1;
# }
# #T_d56ca_row0_col10, #T_d56ca_row10_col0 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_d56ca_row0_col11, #T_d56ca_row11_col0, #T_d56ca_row17_col27, #T_d56ca_row27_col17 {
#   background-color: #edf8b2;
#   color: #000000;
# }
#   background-color: #93d284;
#   color: #000000;
# }
# #T_d56ca_row0_col15, #T_d56ca_row4_col20, #T_d56ca_row10_col20, #T_d56ca_row10_col21, #T_d56ca_row10_col35, #T_d56ca_row10_col36, #T_d56ca_row15_col0, #T_d56ca_row20_col4, #T_d56ca_row20_col10, #T_d56ca_row20_col30, #T_d56ca_row21_col10, #T_d56ca_row25_col30, #T_d56ca_row30_col20, #T_d56ca_row30_col25, #T_d56ca_row35_col10, #T_d56ca_row36_col10 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_d56ca_row0_col16, #T_d56ca_row1_col12, #T_d56ca_row2_col20, #T_d56ca_row2_col21, #T_d56ca_row3_col24, #T_d56ca_row5_col34, #T_d56ca_row12_col1, #T_d56ca_row16_col0, #T_d56ca_row17_col29, #T_d56ca_row17_col35, #T_d56ca_row19_col25, #T_d56ca_row20_col2, #T_d56ca_row20_col32, #T_d56ca_row20_col33, #T_d56ca_row21_col2, #T_d56ca_row22_col25, #T_d56ca_row24_col3, #T_d56ca_row24_col29, #T_d56ca_row25_col19, #T_d56ca_row25_col22, #T_d56ca_row25_col36, #T_d56ca_row29_col17, #T_d56ca_row29_col24, #T_d56ca_row32_col20, #T_d56ca_row33_col20, #T_d56ca_row34_col5, #T_d56ca_row35_col17, #T_d56ca_row36_col25 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_d56ca_row0_col17, #T_d56ca_row0_col33, #T_d56ca_row1_col5, #T_d56ca_row1_col14, #T_d56ca_row1_col18, #T_d56ca_row1_col22, #T_d56ca_row2_col16, #T_d56ca_row2_col22, #T_d56ca_row2_col27, #T_d56ca_row4_col12, #T_d56ca_row4_col14, #T_d56ca_row4_col15, #T_d56ca_row5_col1, #T_d56ca_row5_col14, #T_d56ca_row5_col36, #T_d56ca_row6_col16, #T_d56ca_row6_col25, #T_d56ca_row6_col32, #T_d56ca_row6_col33, #T_d56ca_row8_col16, #T_d56ca_row8_col27, #T_d56ca_row9_col16, #T_d56ca_row9_col28, #T_d56ca_row9_col32, #T_d56ca_row9_col33, #T_d56ca_row10_col22, #T_d56ca_row11_col33, #T_d56ca_row1

# %%
stats.get_factor_names()
# Out:
# Mkt-RF_None
# SMB_None
# HML_None
# RMW_None
# CMA_None
# RF_None
# log_prices_logged
# BND_index
# GDX_index
# QQQ_index
# TLT_index
# TMF_index
# VIX_index
# WTI_index
# returns_shifted_20
# returns_shifted_1
# returns_shifted_7
# vols_volatility60
# sma_3_sma3
# sma_6_sma6_momentum1
# sma_12_sma12_momentum1
# sma_30_sma30_momentum1
# PEG_1yrforward
# aftret_invcapx
# bm
# capital_ratio
# curr_ratio
# gpm
# pcf
# pe_op_dil
# ptb
# quick_ratio
# roa
# roe
# momentum_60_momentum60
# momentum_10_momentum10
# momentum_30_momentum30

# %%
stats.plot_beeswarm_shaps()
