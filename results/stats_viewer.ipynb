# %%
load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
autoreload 2

# %%
from factorlib.statistics import Statistics

# %%
stats = Statistics()
stats.load('wfo_stats.p')
stats.print_statistics_report()
# Out:
# Empty Statistics object created. Load object using load(path: str) method.
#
# FACTOR MODEL ANALYSIS REPORT
# ==============================
# Relative to baseline models:
# Spearman correlation: 0.017100018139658626
# An input array is constant; the correlation coefficient is not defined.
# +--------------+---------+--------+----------+---------+
# |   metric:    | factors |  spy   | buy_hold |  random |
# +--------------+---------+--------+----------+---------+
# | cum. returns |  28.77% | 31.22% |  33.87%  |  -27.8% |
# |    sharpe    |  2.086  | 2.233  |  2.307   |  -2.482 |
# |   sortino    |  3.143  | 3.251  |  3.373   |  -3.182 |
# |     cagr     |  28.95% | 31.42% |  34.08%  | -27.93% |
# |  avg rtrns   |   0.1%  | 0.11%  |  0.12%   |  -0.13% |
# | max drawdown |  -6.8%  | -6.62% |  -6.84%  | -29.47% |
# |  volatility  |  12.53% | 12.56% |  13.05%  |  12.82% |
# |   win rate   |  58.73% | 59.52% |  59.92%  |  43.82% |
# +--------------+---------+--------+----------+---------+

# %%
stats.compute_correlations()
# Out:
# <style type="text/css">
# #T_299c0_row0_col0, #T_299c0_row1_col1, #T_299c0_row2_col2, #T_299c0_row3_col3, #T_299c0_row4_col4, #T_299c0_row5_col5, #T_299c0_row6_col6, #T_299c0_row7_col7, #T_299c0_row8_col8, #T_299c0_row9_col9, #T_299c0_row10_col10, #T_299c0_row10_col11, #T_299c0_row11_col10, #T_299c0_row11_col11, #T_299c0_row12_col12, #T_299c0_row13_col13, #T_299c0_row14_col14, #T_299c0_row15_col15, #T_299c0_row16_col16, #T_299c0_row17_col17, #T_299c0_row18_col18, #T_299c0_row19_col19, #T_299c0_row20_col20, #T_299c0_row21_col21, #T_299c0_row22_col22, #T_299c0_row23_col23, #T_299c0_row24_col24, #T_299c0_row25_col25, #T_299c0_row27_col27, #T_299c0_row28_col28, #T_299c0_row29_col29, #T_299c0_row30_col30, #T_299c0_row32_col32, #T_299c0_row33_col33, #T_299c0_row34_col34, #T_299c0_row35_col35, #T_299c0_row36_col36 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_299c0_row0_col1, #T_299c0_row1_col0, #T_299c0_row3_col8, #T_299c0_row3_col34, #T_299c0_row4_col20, #T_299c0_row4_col35, #T_299c0_row8_col3, #T_299c0_row10_col21, #T_299c0_row10_col36, #T_299c0_row11_col34, #T_299c0_row11_col36, #T_299c0_row20_col4, #T_299c0_row20_col30, #T_299c0_row21_col10, #T_299c0_row25_col35, #T_299c0_row30_col20, #T_299c0_row34_col3, #T_299c0_row34_col11, #T_299c0_row35_col4, #T_299c0_row35_col25, #T_299c0_row36_col10, #T_299c0_row36_col11 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_299c0_row0_col2, #T_299c0_row2_col0, #T_299c0_row3_col13, #T_299c0_row13_col3 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_299c0_row0_col3, #T_299c0_row2_col10, #T_299c0_row3_col0, #T_299c0_row10_col2, #T_299c0_row17_col18, #T_299c0_row18_col17 {
#   background-color: #abdc8d;
#   color: #000000;
# }
# #T_299c0_row0_col4, #T_299c0_row4_col0 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_299c0_row0_col5, #T_299c0_row0_col29, #T_299c0_row1_col23, #T_299c0_row2_col28, #T_299c0_row2_col33, #T_299c0_row4_col10, #T_299c0_row4_col22, #T_299c0_row4_col28, #T_299c0_row4_col34, #T_299c0_row5_col0, #T_299c0_row5_col6, #T_299c0_row5_col9, #T_299c0_row5_col35, #T_299c0_row6_col5, #T_299c0_row6_col17, #T_299c0_row6_col25, #T_299c0_row6_col30, #T_299c0_row7_col12, #T_299c0_row7_col14, #T_299c0_row7_col21, #T_299c0_row7_col30, #T_299c0_row7_col34, #T_299c0_row7_col36, #T_299c0_row9_col5, #T_299c0_row10_col4, #T_299c0_row10_col14, #T_299c0_row11_col29, #T_299c0_row12_col7, #T_299c0_row13_col16, #T_299c0_row14_col7, #T_299c0_row14_col10, #T_299c0_row14_col28, #T_299c0_row14_col30, #T_299c0_row14_col32, #T_299c0_row14_col33, #T_299c0_row15_col16, #T_299c0_row15_col25, #T_299c0_row15_col30, #T_299c0_row16_col13, #T_299c0_row16_col15, #T_299c0_row16_col25, #T_299c0_row16_col30, #T_299c0_row17_col6, #T_299c0_row19_col33, #T_299c0_row21_col7, #T_299c0_row22_col4, #T_299c0_row23_col1, #T_299c0_row25_col6, #T_299c0_row25_col15, #T_299c0_row25_col16, #T_299c0_row28_col2, #T_299c0_row28_col4, #T_299c0_row28_col14, #T_299c0_row29_col0, #T_299c0_row29_col11, #T_299c0_row30_col6, #T_299c0_row30_col7, #T_299c0_row30_col14, #T_299c0_row30_col15, #T_299c0_row30_col16, #T_299c0_row32_col14, #T_299c0_row33_col2, #T_299c0_row33_col14, #T_299c0_row33_col19, #T_299c0_row34_col4, #T_299c0_row34_col7, #T_299c0_row35_col5, #T_299c0_row36_col7 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_299c0_row0_col6, #T_299c0_row6_col0 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_299c0_row0_col7, #T_299c0_row1_col10, #T_299c0_row2_col7, #T_299c0_row7_col0, #T_299c0_row7_col2, #T_299c0_row7_col9, #T_299c0_row9_col7, #T_299c0_row10_col1, #T_299c0_row10_col19, #T_299c0_row19_col10, #T_299c0_row22_col25, #T_299c0_row25_col22 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_299c0_row0_col8, #T_299c0_row0_col19, #T_299c0_row8_col0, #T_299c0_row8_col13, #T_299c0_row13_col8, #T_299c0_row19_col0, #T_299c0_row29_col32, #T_299c0_row32_col29 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_299c0_row0_col9, #T_299c0_row9_col0, #T_299c0_row20_col35, #T_299c0_row35_col20 {
#   background-color: #00522e;
#   color: #f1f1f1;
# }
# #T_299c0_row0_col10, #T_299c0_row5_col33, #T_299c0_row10_col0, #T_299c0_row33_col5 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_299c0_row0_col11, #T_299c0_row11_col0 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_299c0_row0_col12, #T_299c0_row3_col17, #T_299c0_row4_col17, #T_299c0_row7_col17, #T_299c0_row8_col17, #T_299c0_row8_col22, #T_299c0_row9_col12, #T_299c0_row10_col16, #T_299c0_row10_col22, #T_299c0_row11_col22, #T_299c0_row12_col0, #T_299c0_row12_col9, #T_299c0_row12_col15, #T_299c0_row15_col12, #T_299c0_row16_col10, #T_299c0_row16_col22, #T_299c0_row17_col3, #T_299c0_row17_col4, #T_299c0_row17_col7, #T_299c0_row17_col8, #T_299c0_row18_col19, #T_299c0_row18_col35, #T_299c0_row19_col18, #T_299c0_row20_col23, #T_299c0_row22_col8, #T_299c0_row22_col10, #T_299c0_row22_col11, #T_299c0_row22_col16, #T_299c0_row22_col29, #T_299c0_row23_col20, #T_299c0_row23_col34, #T_299c0_row23_col35, #T_299c0_row29_col22, #T_299c0_row34_col23, #T_299c0_row35_col18, #T_299c0_row35_col23 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_299c0_row0_col13, #T_299c0_row13_col0 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_299c0_row0_col14, #T_299c0_row0_col18, #T_299c0_row0_col24, #T_299c0_row0_col33, #T_299c0_row1_col17, #T_299c0_row1_col29, #T_299c0_row1_col32, #T_299c0_row2_col25, #T_299c0_row2_col32, #T_299c0_row2_col34, #T_299c0_row3_col14, #T_299c0_row3_col18, #T_299c0_row3_col27, #T_299c0_row3_col28, #T_299c0_row3_col30, #T_299c0_row3_col32, #T_299c0_row3_col33, #T_299c0_row4_col24, #T_299c0_row4_col25, #T_299c0_row4_col27, #T_299c0_row5_col7, #T_299c0_row5_col13, #T_299c0_row6_col15, #T_299c0_row6_col18, #T_299c0_row6_col23, #T_299c0_row7_col5, #T_299c0_row8_col12, #T_299c0_row8_col24, #T_299c0_row9_col17, #T_299c0_row9_col24, #T_299c0_row9_col33, #T_299c0_row10_col23, #T_299c0_row10_col27, #T_299c0_row10_col30, #T_299c0_row11_col18, #T_299c0_row11_col23, #T_299c0_row11_col27, #T_299c0_row11_col30, #T_299c0_row12_col8, #T_299c0_row12_col21, #T_299c0_row12_col34, #T_299c0_row12_col36, #T_299c0_row13_col5, #T_299c0_row14_col0, #T_299c0_row14_col3, #T_299c0_row14_col23, #T_299c0_row14_col24, #T_299c0_row15_col6, #T_299c0_row15_col18, #T_299c0_row15_col23, #T_299c0_row17_col1, #T_299c0_row17_col9, #T_299c0_row18_col0, #T_299c0_row18_col3, #T_299c0_row18_col6, #T_299c0_row18_col11, #T_299c0_row18_col15, #T_299c0_row21_col12, #T_299c0_row22_col24, #T_299c0_row23_col6, #T_299c0_row23_col10, #T_299c0_row23_col11, #T_299c0_row23_col14, #T_299c0_row23_col15, #T_299c0_row24_col0, #T_299c0_row24_col4, #T_299c0_row24_col8, #T_299c0_row24_col9, #T_299c0_row24_col14, #T_299c0_row24_col22, #T_299c0_row25_col2, #T_299c0_row25_col4, #T_299c0_row27_col3, #T_299c0_row27_col4, #T_299c0_row27_col10, #T_299c0_row27_col11, #T_299c0_row28_col3, #T_299c0_row29_col1, #T_299c0_row30_col3, #T_299c0_row30_col10, #T_299c0_row30_col11, #T_299c0_row32_col1, #T_299c0_row32_col2, #T_299c0_row32_col3, #T_299c0_row33_col0, #T_299c0_row33_col3, #T_299c0_row33_col9, #T_299c0_row34_col2, #T_299c0_row34_col12, #T_299c0_row36_col12 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_299c0_row0_col15, #T_299c0_row10_col20, #T_299c0_row10_col34, #T_299c0_row10_col35, #T_299c0_row12_col30, #T_299c0_row12_col33, #T_299c0_row15_col0, #T_299c0_row17_col32, #T_299c0_row19_col29, #T_299c0_row20_col10, #T_299c0_row29_col19, #T_299c0_row30_col12, #T_299c0_row30_col35, #T_299c0_row32_col17, #T_299c0_row33_col12, #T_299c0_row34_col10, #T_299c0_row35_col10, #T_299c0_row35_col30 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_299c0_row0_col16, #T_299c0_row1_col24, #T_299c0_row2_col21, #T_299c0_row2_col30, #T_299c0_row2_col36, #T_299c0_row4_col29, #T_299c0_row5_col19, #T_299c0_row6_col29, #T_299c0_row8_col29, #T_299c0_row8_col30, #T_299c0_row10_col29, #T_299c0_row12_col29, #T_299c0_row14_col25, #T_299c0_row15_col29, #T_299c0_row16_col0, #T_299c0_row16_col29, #T_299c0_row19_col5, #T_299c0_row19_col24, #T_299c0_row19_col28, #T_299c0_r

# %%
stats.get_factor_names()
# Out:
# Mkt-RF_None
# SMB_None
# HML_None
# RMW_None
# CMA_None
# RF_None
# log_prices_logged
# BND_index
# GDX_index
# QQQ_index
# TLT_index
# TMF_index
# VIX_index
# WTI_index
# returns_shifted_20
# returns_shifted_1
# returns_shifted_7
# vols_volatility60
# sma_3_sma3
# sma_6_sma6_momentum1
# sma_12_sma12_momentum1
# sma_30_sma30_momentum1
# PEG_1yrforward
# aftret_invcapx
# bm
# capital_ratio
# curr_ratio
# gpm
# pcf
# pe_op_dil
# ptb
# quick_ratio
# roa
# roe
# momentum_60_momentum60
# momentum_10_momentum10
# momentum_30_momentum30

# %%
stats.plot_beeswarm_shaps()
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
