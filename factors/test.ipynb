# %%
import pandas as pd
df = pd.read_csv('../data/wrds_ratios_formatted.csv', header=[0, 1], index_col=0)

# %%
unzip(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 unzip(df.columns)
#
# NameError: name 'unzip' is not defined

# %%
df['AIR']
# Out:
#              PEG_1yrforward  aftret_invcapx     bm  capital_ratio  curr_ratio  \
# public_date
# 2001-01-31           -0.499           0.077  1.439          0.346       2.955
# 2001-02-28           -0.464           0.077  1.439          0.346       2.955
# 2001-03-31           -0.427           0.077  1.439          0.346       2.955
# 2001-04-30           -0.415           0.066  1.107          0.346       2.993
# 2001-05-31           -0.518           0.066  1.107          0.346       2.993
# ...                     ...             ...    ...            ...         ...
# 2019-08-31              NaN           0.083  0.865          0.135       2.664
# 2019-09-30              NaN           0.083  0.865          0.135       2.664
# 2019-10-31              NaN           0.083  0.605          0.182       2.750
# 2019-11-30              NaN           0.083  0.605          0.182       2.750
# 2019-12-31              NaN           0.083  0.605          0.182       2.750
#
# ...
