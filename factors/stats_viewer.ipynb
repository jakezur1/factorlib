# %%
load_ext autoreload

# %%
autoreload 2

# %%
from factorlib.statistics import Statistics

# %%
stats = Statistics()
stats.load('../results/wfo_stats.p')
corr_matrix = stats.compute_correlations()
corr_matrix
# Out:
# Empty Statistics object created. Load object using load(path: str) method.
# <style type="text/css">
# #T_c0887_row0_col0, #T_c0887_row1_col1, #T_c0887_row2_col2, #T_c0887_row3_col3, #T_c0887_row4_col4, #T_c0887_row5_col5, #T_c0887_row6_col6, #T_c0887_row7_col7, #T_c0887_row8_col8, #T_c0887_row9_col9, #T_c0887_row10_col10, #T_c0887_row10_col11, #T_c0887_row11_col10, #T_c0887_row11_col11, #T_c0887_row12_col12, #T_c0887_row13_col13, #T_c0887_row14_col14, #T_c0887_row15_col15, #T_c0887_row16_col16, #T_c0887_row17_col17, #T_c0887_row18_col18, #T_c0887_row19_col19, #T_c0887_row20_col20, #T_c0887_row21_col21, #T_c0887_row22_col22, #T_c0887_row23_col23, #T_c0887_row24_col24, #T_c0887_row25_col25, #T_c0887_row26_col26, #T_c0887_row27_col27, #T_c0887_row28_col28, #T_c0887_row29_col29, #T_c0887_row30_col30, #T_c0887_row31_col31, #T_c0887_row32_col32, #T_c0887_row33_col33, #T_c0887_row34_col34, #T_c0887_row35_col35, #T_c0887_row36_col36 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...
